# %% [markdown]
# # Carga del dataset
# Gracias a las utiliades de keras se pueden cargar las imágenes del dataset de una forma muy eficiente, haciendo uso de la clase ImageDataGenerator. Esta utilidad carga las imágenes a medida que se necesitan, como cualquier otro generador en Python, ahorrando el uso de memoria necesaria para el entrenamiento. Además, inlcuye opciones para aplicar Data Augmentation durante la carga. Al tratarse de un generador sobre el que se va a iterar no se puede saber el tamaño de los datos que contiene, por lo que ese valor se ha introducido a mano en esta celda también.

# %%
from keras.preprocessing.image import ImageDataGenerator

base_path = 'F:\\master\\vision\\pr_learning\\dataset'
data_entrenamiento = f'{base_path}\\train\\'
data_validacion = f'{base_path}\\validation\\'
data_test = f'{base_path}\\test\\'

training_imgs = 35444
val_imgs = 2614
test_imgs = 1204

entrenamiento_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

val_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1. / 255)

# %% [markdown]
# Con el método flow_from_directory, el generador escanea un directorio del equipo en busca de imágenes para cargar. La colocación de las imágenes en los árboles del directorio es muy importante para hacer uso de esta utilidad. En nuestro caso hay 3 directorios principales --train, validation y test--, con las imágenes que se emplearán en cada una de las fases del entrenamiento. Esos 3 directorios son los que se introducirán en el método flow_from_directory, utilizando cada uno de ellos un generador distinto. Los 3 directorios principales que acabamos de señalar comparten la misma estructura interna, ya que tienen en su interior 43 directorios --en el dataset hay 43 clases, un directorio por cada clase del clasificador--, y dentro de cada carpeta las imágenes correspondientes a la misma clase.

# %%
batch_size_ff = 128

entrenamiento_generador_ff = entrenamiento_datagen.flow_from_directory(
    data_entrenamiento,
    target_size=(32, 32),
    batch_size=batch_size_ff,
    class_mode='categorical')

validacion_generador_ff = val_datagen.flow_from_directory(
    data_validacion,
    target_size=(32, 32),
    batch_size=batch_size_ff,
    class_mode='categorical')

test_generador_ff = test_datagen.flow_from_directory(
    data_test,
    target_size=(32, 32),
    batch_size=batch_size_ff,
    class_mode='categorical')
# Out:
# Found 35444 images belonging to 43 classes.
# Found 2614 images belonging to 43 classes.
# Found 1204 images belonging to 43 classes.

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # Summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1,step=len(model_history.history['accuracy'])/10))
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1,step=len(model_history.history['loss'])/10))
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# # Creación de modelos
# ## ffNN
# Para la primera parte del ejercicio, se crearon 3 modelos distintos con el objetivo de poder compararlos. Estas funciones, que se emplearán más adelante, crean los modelos para ser utilizados.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, BatchNormalization

def build_model_v1():
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))
    model.add(Dense(128))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(128))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(43))
    model.add(Activation('softmax'))
    return model

def build_model_v2():
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))
    model.add(Dense(128))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(64))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(16))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(43))
    model.add(Activation('softmax'))
    return model

def build_model_v3():
    model = Sequential()
    model.add(Flatten(input_shape=(32, 32, 3)))
    model.add(Dense(1024, activation="relu"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(512, activation="relu"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(64, activation="relu"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(64, activation="relu"))
    model.add(BatchNormalization())
    model.add(Activation('relu'))   
    model.add(Dense(43))
    model.add(Activation('softmax'))
    return model

# %% [markdown]
# ### Modelo 1

# %%
# Feed forward dense model
# Here it is not allowed to use convolutional layers
# You may use any regularizacion (see class slides)

model = build_model_v1()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               393344
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# activation (Activation)      (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                5547
# _________________________________________________________________
# activation_2 (Activation)    (None, 43)                0
# =================================================================
# Total params: 416,427
# Trainable params: 415,915
# Non-trainable params: 512
# _________________________________________________________________

# %%
# Training
import time
start = time.time()
history = model.fit_generator(entrenamiento_generador_ff, steps_per_epoch=training_imgs//batch_size_ff, epochs=30, verbose=1, validation_data=validacion_generador_ff, validation_steps=val_imgs//batch_size_ff)
end = time.time()

loss, acc = model.evaluate_generator(test_generador_ff, test_imgs//batch_size_ff if test_imgs//batch_size_ff > 0 else 1, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', acc)

plot_model_history(history)
print("Training MLP took " + str(end - start) + " seconds")
# Out:
# WARNING:tensorflow:From <ipython-input-6-b5b0d8124321>:4: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/30
# 276/276 [==============================] - 38s 138ms/step - loss: 1.8362 - accuracy: 0.5093 - val_loss: 1.3985 - val_accuracy: 0.5922
# Epoch 2/30
# 276/276 [==============================] - 24s 86ms/step - loss: 0.9374 - accuracy: 0.7300 - val_loss: 1.0202 - val_accuracy: 0.6902
# Epoch 3/30
# 276/276 [==============================] - 23s 85ms/step - loss: 0.6957 - accuracy: 0.7943 - val_loss: 0.8408 - val_accuracy: 0.7336
# Epoch 4/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.5900 - accuracy: 0.8227 - val_loss: 0.8475 - val_accuracy: 0.7371
# Epoch 5/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.5357 - accuracy: 0.8378 - val_loss: 0.9793 - val_accuracy: 0.7082
# Epoch 6/30
# 276/276 [==============================] - 24s 85ms/step - loss: 0.4830 - accuracy: 0.8541 - val_loss: 0.6197 - val_accuracy: 0.8191
# Epoch 7/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4355 - accuracy: 0.8680 - val_loss: 0.9617 - val_accuracy: 0.7223
# Epoch 8/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4258 - accuracy: 0.8701 - val_loss: 0.7334 - val_accuracy: 0.7891
# Epoch 9/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3867 - accuracy: 0.8816 - val_loss: 0.6282 - val_accuracy: 0.8043
# Epoch 10/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3554 - accuracy: 0.8894 - val_loss: 0.5346 - val_accuracy: 0.8359
# Epoch 11/30
# 276/276 [==============================] - 23s 83ms/step - loss: 0.3365 - accuracy: 0.8973 - val_loss: 0.5636 - val_accuracy: 0.8395
# Epoch 12/30
# 276/276 [==============================] - 24s 86ms/step - loss: 0.3287 - accuracy: 0.8989 - val_loss: 0.6532 - val_accuracy: 0.8207
# Epoch 13/30
# 276/276 [==============================] - 23s 85ms/step - loss: 0.3162 - accuracy: 0.9015 - val_loss: 0.6566 - val_accuracy: 0.8117
# Epoch 14/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3055 - accuracy: 0.9058 - val_loss: 0.4199 - val_accuracy: 0.8816
# Epoch 15/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.2907 - accuracy: 0.9098 - val_loss: 0.4400 - val_accuracy: 0.8738
# Epoch 16/30
# 276/276 [==============================] - 28s 101ms/step - loss: 0.2826 - accuracy: 0.9122 - val_loss: 0.4421 - val_accuracy: 0.8762
# Epoch 17/30
# 276/276 [==============================] - 25s 91ms/step - loss: 0.2684 - accuracy: 0.9177 - val_loss: 0.4083 - val_accuracy: 0.8902
# Epoch 18/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2634 - accuracy: 0.9177 - val_loss: 0.6154 - val_accuracy: 0.8359
# Epoch 19/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2499 - accuracy: 0.9225 - val_loss: 0.4746 - val_accuracy: 0.8684
# Epoch 20/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2463 - accuracy: 0.9208 - val_loss: 0.3993 - val_accuracy: 0.8949
# Epoch 21/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2430 - accuracy: 0.9241 - val_loss: 0.4551 - val_accuracy: 0.8707
# Epoch 22/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2387 - accuracy: 0.9252 - val_loss: 0.5147 - val_accuracy: 0.8543
# Epoch 23/30
# 276/276 [==============================] - 25s 91ms/step - loss: 0.2281 - accuracy: 0.9277 - val_loss: 0.4228 - val_accuracy: 0.8875
# Epoch 24/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2237 - accuracy: 0.9285 - val_loss: 0.4323 - val_accuracy: 0.8859
# Epoch 25/30
# 276/276 [==============================] - 25s 91ms/step - loss: 0.2127 - accuracy: 0.9323 - val_loss: 0.3553 - val_accuracy: 0.9066
# Epoch 26/30
# 276/276 [==============================] - 25s 91ms/step - loss: 0.2097 - accuracy: 0.9339 - val_loss: 0.4789 - val_accuracy: 0.8777
# Epoch 27/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.2132 - accuracy: 0.9317 - val_loss: 0.4367 - val_accuracy: 0.8836
# Epoch 28/30
# 276/276 [==============================] - 25s 90ms/step - loss: 0.1977 - accuracy: 0.9384 - val_loss: 0.4455 - val_accuracy: 0.8789
# Epoch 29/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.1998 - accuracy: 0.9370 - val_loss: 0.4524 - val_accuracy: 0.8832
# Epoch 30/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.1857 - accuracy: 0.9411 - val_loss: 0.3387 - val_accuracy: 0.9180
# WARNING:tensorflow:From <ipython-input-6-b5b0d8124321>:7: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# Test loss: 2.792046546936035
# Test accuracy: 0.5694444179534912
# Training MLP took 745.5704758167267 seconds

# %% [markdown]
# ### Modelo 2

# %%
# Feed forward dense model
# Here it is not allowed to use convolutional layers
# You may use any regularizacion (see class slides)

model = build_model_v2()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               393344
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32)                128
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16)                64
# _________________________________________________________________
# activation_6 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 43)                731
# _________________________________________________________________
# activation_7 (Activation)    (None, 43)                0
# =================================================================
# Total params: 405,899
# Trainable params: 405,419
# Non-trainable params: 480
# _________________________________________________________________

# %%
# Training
import time
start = time.time()
history = model.fit_generator(entrenamiento_generador_ff, steps_per_epoch=training_imgs//batch_size_ff, epochs=30, verbose=1, validation_data=validacion_generador_ff, validation_steps=val_imgs//batch_size_ff)
end = time.time()

loss, acc = model.evaluate_generator(test_generador_ff, test_imgs//batch_size_ff if test_imgs//batch_size_ff > 0 else 1, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', acc)

plot_model_history(history)
print("Training MLP took " + str(end - start) + " seconds")
# Out:
# Epoch 1/30
# 276/276 [==============================] - 25s 89ms/step - loss: 2.7393 - accuracy: 0.3257 - val_loss: 2.4380 - val_accuracy: 0.3617
# Epoch 2/30
# 276/276 [==============================] - 24s 86ms/step - loss: 1.7241 - accuracy: 0.5266 - val_loss: 2.0367 - val_accuracy: 0.4344
# Epoch 3/30
# 276/276 [==============================] - 23s 84ms/step - loss: 1.2702 - accuracy: 0.6394 - val_loss: 1.3186 - val_accuracy: 0.6223
# Epoch 4/30
# 276/276 [==============================] - 23s 84ms/step - loss: 1.0060 - accuracy: 0.7057 - val_loss: 1.1472 - val_accuracy: 0.6508
# Epoch 5/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.8536 - accuracy: 0.7430 - val_loss: 0.8614 - val_accuracy: 0.7355
# Epoch 6/30
# 276/276 [==============================] - 23s 85ms/step - loss: 0.7561 - accuracy: 0.7714 - val_loss: 0.8766 - val_accuracy: 0.7367
# Epoch 7/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.6814 - accuracy: 0.7932 - val_loss: 0.7415 - val_accuracy: 0.7641
# Epoch 8/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.6202 - accuracy: 0.8087 - val_loss: 0.7087 - val_accuracy: 0.7887
# Epoch 9/30
# 276/276 [==============================] - 24s 85ms/step - loss: 0.5738 - accuracy: 0.8238 - val_loss: 0.7006 - val_accuracy: 0.7887
# Epoch 10/30
# 276/276 [==============================] - 24s 86ms/step - loss: 0.5399 - accuracy: 0.8332 - val_loss: 0.7183 - val_accuracy: 0.7902
# Epoch 11/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.5020 - accuracy: 0.8443 - val_loss: 0.6443 - val_accuracy: 0.7922
# Epoch 12/30
# 276/276 [==============================] - 24s 86ms/step - loss: 0.4916 - accuracy: 0.8460 - val_loss: 0.6848 - val_accuracy: 0.7996
# Epoch 13/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4674 - accuracy: 0.8553 - val_loss: 0.5666 - val_accuracy: 0.8258
# Epoch 14/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4336 - accuracy: 0.8654 - val_loss: 0.5701 - val_accuracy: 0.8246
# Epoch 15/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4206 - accuracy: 0.8692 - val_loss: 0.6225 - val_accuracy: 0.8246
# Epoch 16/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4093 - accuracy: 0.8735 - val_loss: 0.5454 - val_accuracy: 0.8316
# Epoch 17/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.4033 - accuracy: 0.8751 - val_loss: 0.5597 - val_accuracy: 0.8320
# Epoch 18/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3841 - accuracy: 0.8794 - val_loss: 0.5365 - val_accuracy: 0.8496
# Epoch 19/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3743 - accuracy: 0.8833 - val_loss: 0.6709 - val_accuracy: 0.8129
# Epoch 20/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3493 - accuracy: 0.8905 - val_loss: 0.5959 - val_accuracy: 0.8266
# Epoch 21/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3400 - accuracy: 0.8952 - val_loss: 0.4905 - val_accuracy: 0.8621
# Epoch 22/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3516 - accuracy: 0.8891 - val_loss: 0.4648 - val_accuracy: 0.8645
# Epoch 23/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3218 - accuracy: 0.8989 - val_loss: 0.5185 - val_accuracy: 0.8496
# Epoch 24/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3291 - accuracy: 0.8975 - val_loss: 0.4811 - val_accuracy: 0.8711
# Epoch 25/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3174 - accuracy: 0.9017 - val_loss: 0.5058 - val_accuracy: 0.8598
# Epoch 26/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.3108 - accuracy: 0.9023 - val_loss: 0.4162 - val_accuracy: 0.8848
# Epoch 27/30
# 276/276 [==============================] - 23s 83ms/step - loss: 0.3009 - accuracy: 0.9050 - val_loss: 0.4260 - val_accuracy: 0.8742
# Epoch 28/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.2934 - accuracy: 0.9073 - val_loss: 0.7499 - val_accuracy: 0.8059
# Epoch 29/30
# 276/276 [==============================] - 23s 84ms/step - loss: 0.2802 - accuracy: 0.9120 - val_loss: 0.4964 - val_accuracy: 0.8582
# Epoch 30/30
# 276/276 [==============================] - 23s 85ms/step - loss: 0.2839 - accuracy: 0.9112 - val_loss: 0.4405 - val_accuracy: 0.8750
# Test loss: 2.7677083015441895
# Test accuracy: 0.5451388955116272
# Training MLP took 702.507782459259 seconds

# %% [markdown]
# ### Modelo 3

# %%
# Feed forward dense model
# Here it is not allowed to use convolutional layers
# You may use any regularizacion (see class slides)

model = build_model_v3()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              3146752
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_8 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# activation_9 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                32832
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                4160
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# activation_11 (Activation)   (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 43)                2795
# _________________________________________________________________
# activation_12 (Activation)   (None, 43)                0
# =================================================================
# Total params: 3,717,995
# Trainable params: 3,714,667
# Non-trainable params: 3,328
# _________________________________________________________________

# %%
# Training
import time
start = time.time()
history = model.fit_generator(entrenamiento_generador_ff, steps_per_epoch=training_imgs//batch_size_ff, epochs=30, verbose=1, validation_data=validacion_generador_ff, validation_steps=val_imgs//batch_size_ff)
end = time.time()

loss, acc = model.evaluate_generator(test_generador_ff, test_imgs//batch_size_ff if test_imgs//batch_size_ff > 0 else 1, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', acc)

plot_model_history(history)
print("Training MLP took " + str(end - start) + " seconds")
# Out:
# Epoch 1/30
# 276/276 [==============================] - 25s 91ms/step - loss: 2.6943 - accuracy: 0.2993 - val_loss: 2.8508 - val_accuracy: 0.2723
# Epoch 2/30
# 276/276 [==============================] - 25s 90ms/step - loss: 1.6259 - accuracy: 0.5191 - val_loss: 2.4132 - val_accuracy: 0.3195
# Epoch 3/30
# 276/276 [==============================] - 25s 89ms/step - loss: 1.1624 - accuracy: 0.6432 - val_loss: 1.6305 - val_accuracy: 0.5273
# Epoch 4/30
# 276/276 [==============================] - 24s 88ms/step - loss: 0.8892 - accuracy: 0.7229 - val_loss: 1.1952 - val_accuracy: 0.6469
# Epoch 5/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.7100 - accuracy: 0.7763 - val_loss: 1.1507 - val_accuracy: 0.6719
# Epoch 6/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.6006 - accuracy: 0.8100 - val_loss: 0.8455 - val_accuracy: 0.7480
# Epoch 7/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.5273 - accuracy: 0.8334 - val_loss: 0.7366 - val_accuracy: 0.7672
# Epoch 8/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.4544 - accuracy: 0.8547 - val_loss: 0.9623 - val_accuracy: 0.7246
# Epoch 9/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.4200 - accuracy: 0.8656 - val_loss: 0.7054 - val_accuracy: 0.7820
# Epoch 10/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.3820 - accuracy: 0.8776 - val_loss: 0.9286 - val_accuracy: 0.7223
# Epoch 11/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.3874 - accuracy: 0.8752 - val_loss: 0.9076 - val_accuracy: 0.7551
# Epoch 12/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.3335 - accuracy: 0.8937 - val_loss: 0.6436 - val_accuracy: 0.8078
# Epoch 13/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.3145 - accuracy: 0.8991 - val_loss: 0.6818 - val_accuracy: 0.7957
# Epoch 14/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.2807 - accuracy: 0.9102 - val_loss: 0.5302 - val_accuracy: 0.8578
# Epoch 15/30
# 276/276 [==============================] - 25s 89ms/step - loss: 0.2787 - accuracy: 0.9100 - val_loss: 0.8124 - val_accuracy: 0.7660
# Epoch 16/30
# 276/276 [==============================] - 25s 91ms/step - loss: 0.2685 - accuracy: 0.9126 - val_loss: 0.5484 - val_accuracy: 0.8461
# Epoch 17/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.2501 - accuracy: 0.9207 - val_loss: 0.5159 - val_accuracy: 0.8531
# Epoch 18/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.2239 - accuracy: 0.9290 - val_loss: 0.6778 - val_accuracy: 0.8160
# Epoch 19/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.2179 - accuracy: 0.9283 - val_loss: 0.3974 - val_accuracy: 0.8867
# Epoch 20/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.2170 - accuracy: 0.9308 - val_loss: 0.4694 - val_accuracy: 0.8727
# Epoch 21/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1864 - accuracy: 0.9385 - val_loss: 0.4444 - val_accuracy: 0.8668
# Epoch 22/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1991 - accuracy: 0.9356 - val_loss: 0.4826 - val_accuracy: 0.8711
# Epoch 23/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1708 - accuracy: 0.9441 - val_loss: 0.4448 - val_accuracy: 0.8805
# Epoch 24/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1642 - accuracy: 0.9457 - val_loss: 0.3511 - val_accuracy: 0.9039
# Epoch 25/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1600 - accuracy: 0.9480 - val_loss: 0.4493 - val_accuracy: 0.8801
# Epoch 26/30
# 276/276 [==============================] - 24s 88ms/step - loss: 0.1562 - accuracy: 0.9482 - val_loss: 0.4213 - val_accuracy: 0.8848
# Epoch 27/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1554 - accuracy: 0.9485 - val_loss: 0.6118 - val_accuracy: 0.8574
# Epoch 28/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1457 - accuracy: 0.9520 - val_loss: 0.3475 - val_accuracy: 0.9062
# Epoch 29/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1399 - accuracy: 0.9541 - val_loss: 0.4607 - val_accuracy: 0.8813
# Epoch 30/30
# 276/276 [==============================] - 24s 87ms/step - loss: 0.1464 - accuracy: 0.9527 - val_loss: 0.5081 - val_accuracy: 0.8738
# Test loss: 3.6827802658081055
# Test accuracy: 0.4982638955116272
# Training MLP took 734.1059007644653 seconds

# %% [markdown]
# ## Red convolucional

# %%
batch_size_cnn = 512

entrenamiento_generador_cnn = entrenamiento_datagen.flow_from_directory(
    data_entrenamiento,
    target_size=(32, 32),
    batch_size=batch_size_cnn,
    class_mode='categorical')

validacion_generador_cnn = val_datagen.flow_from_directory(
    data_validacion,
    target_size=(32, 32),
    batch_size=batch_size_ff,
    class_mode='categorical')

test_generador_cnn = test_datagen.flow_from_directory(
    data_test,
    target_size=(32, 32),
    batch_size=batch_size_cnn,
    class_mode='categorical')
# Out:
# Found 35444 images belonging to 43 classes.
# Found 2614 images belonging to 43 classes.
# Found 1204 images belonging to 43 classes.

# %% [markdown]
# Al igual que se hizo con las ffNN, antes de experimetar, se define una función que crea el modelo convolucional.

# %%
from keras.models import Model
from keras.layers import Dense, Activation, Flatten, Input, BatchNormalization, Conv2D, MaxPooling2D

def create_block(block_input, n_filtros):
    x = block_input
    for i in range(2):
        x = Conv2D(n_filtros, kernel_size=(3,3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
    return x

def build_conv(): # De https://www.kaggle.com/mahtabshaan/autoencoder-as-feature-extractor-cifar10
    net_input = Input((32,32,3))

    block1 = create_block(net_input, 32)
    x = MaxPooling2D(pool_size=(2, 2))(block1)

    block2 = create_block(x, 64)
    x = MaxPooling2D(pool_size=(2, 2))(block2)

    block3 = create_block(x, 128)
    x = MaxPooling2D(pool_size=(2, 2))(block3)

    x = Flatten()(x)
    output = Dense(43, activation='softmax')(x)
    return Model(net_input, output)

# %% [markdown]
# Una vez definida la función, se crea y experimenta con ella

# %%
# Convolutional Neural Network (CNN)
# Here you are allowed to use convolutional layers
# You may use also any regularizacion (see class slides)

import keras.backend as K

model = build_conv()

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_13 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_14 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_15 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_18 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 43)                88107
# =================================================================
# Total params: 376,907
# Trainable params: 376,011
# Non-trainable params: 896
# _________________________________________________________________

# %%
# Training
import time
start = time.time()
history = model.fit_generator(entrenamiento_generador_cnn, steps_per_epoch=training_imgs//batch_size_cnn, epochs=10, verbose=1, validation_data=validacion_generador_cnn, validation_steps=val_imgs//batch_size_cnn)
end = time.time()

loss, acc = model.evaluate_generator(test_generador_cnn, test_imgs//batch_size_cnn if test_imgs//batch_size_cnn > 0 else 1, verbose=0)
print('Test loss:', loss)
print('Test accuracy:', acc)

plot_model_history(history)
print("Training MLP took " + str(end - start) + " seconds")
# Out:
# Epoch 1/10
# 69/69 [==============================] - 107s 2s/step - loss: 1.4192 - accuracy: 0.6107 - val_loss: 3.8389 - val_accuracy: 0.0234
# Epoch 2/10
# 69/69 [==============================] - 105s 2s/step - loss: 0.2730 - accuracy: 0.9141 - val_loss: 3.5382 - val_accuracy: 0.0812
# Epoch 3/10
# 69/69 [==============================] - 105s 2s/step - loss: 0.1160 - accuracy: 0.9664 - val_loss: 2.9185 - val_accuracy: 0.2297
# Epoch 4/10
# 69/69 [==============================] - 108s 2s/step - loss: 0.0789 - accuracy: 0.9770 - val_loss: 2.5070 - val_accuracy: 0.3656
# Epoch 5/10
# 69/69 [==============================] - 112s 2s/step - loss: 0.0552 - accuracy: 0.9843 - val_loss: 1.5709 - val_accuracy: 0.5375
# Epoch 6/10
# 69/69 [==============================] - 113s 2s/step - loss: 0.0429 - accuracy: 0.9883 - val_loss: 0.9864 - val_accuracy: 0.7125
# Epoch 7/10
# 69/69 [==============================] - 110s 2s/step - loss: 0.0308 - accuracy: 0.9915 - val_loss: 0.5193 - val_accuracy: 0.8313
# Epoch 8/10
# 69/69 [==============================] - 111s 2s/step - loss: 0.0275 - accuracy: 0.9926 - val_loss: 0.2763 - val_accuracy: 0.9109
# Epoch 9/10
# 69/69 [==============================] - 124s 2s/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.1157 - val_accuracy: 0.9641
# Epoch 10/10
# 69/69 [==============================] - 120s 2s/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 0.0613 - val_accuracy: 0.9844
# Test loss: 1.540651798248291
# Test accuracy: 0.75
# Training MLP took 1135.3245000839233 seconds
